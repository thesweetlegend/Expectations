# %% [markdown]
# <a href="https://colab.research.google.com/github/thesweetlegend/Expectations/blob/master/watermark_thadchayani.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#There's a version where you can see the equalization, and one where you
#can only see the thresholding.
#Feel free to check how each section runs.
import cv2
import numpy as np
from matplotlib import pyplot as plt
from skimage import exposure

#these 4 lines only have thresholding, uncomment this section if you don't want equalization
#cat = cv2.imread(r'/content/watermark_cat.png')
#ret,thresh1 = cv2.threshold(cat,110,255,cv2.THRESH_BINARY)
#titles = ['Original Image','Binary Thresholding']
#images = [cat, thresh1]

#these 5 lines contain thresholding with equalization, uncomment this section if you want equalization included
#cat = plt.imread(r'/content/watermark_cat.png')
#ret,thresh1 = cv2.threshold(cat,0.70,1,cv2.THRESH_BINARY)
#clean_cat = exposure.equalize_hist(thresh1)
#titles = ['Original Image','Binary Thresholding']
#images = [cat, clean_cat]

for i in range(2):
    plt.subplot(1,2,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])

plt.show()

plt.imshow(images[1])
plt.show()

img_path = r'/content/updated_cat.jpg'
plt.imsave(img_path, images[1])
